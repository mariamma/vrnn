# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.ion()

# %%
file_path = './rnn_gauss_out.csv'
df = pd.read_csv(file_path, header=None, nrows = 100)

# %%
df.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0 -0.151714  0.050396  0.538625 -0.243348  0.091887  0.204186  0.130473
# 1  0.165838  0.031520 -0.336076  0.277684 -0.560757  0.067852  0.226264
# 2  0.457332  0.092089  0.105672  0.069472  0.176440  0.140214 -0.567190
# 3  0.186826  0.198372  0.253672 -0.250396  0.024026  0.264934  0.098339
# 4 -0.059940 -0.218329  0.059032  0.019311  0.111252  0.254482  0.103141
#
#        7         8         9     ...      3990      3991      3992      3993  \
# 0 -0.032933  0.149343  0.220128  ... -0.128406 -0.105200  0.079948 -0.090039
# 1  0.194572  0.092105 -0.150292  ...  0.389512 -0.456201 -0.145868  0.290835
# 2 -0.395297  0.230843  0.258138  ... -0.438476 -0.273627 -0.052297 -0.163545
# 3  0.160340 -0.376465 -0.112168  ...  0.210929  0.137758 -0.090787 -0.058537
# 4  0.060996  0.052040  0.024074  ...  0.224952 -0.114969 -0.062888  0.262272
#
#        3994      3995      3996      3997      3998      3999
# ...

# %%
row = df.iloc[1].to_numpy()

# %% [raw]
# plt.plot(row, list(range(4000))
# plt.show(block=True)

# %%
y = list(range(4000))

# %%
import matplotlib

# %%
matplotlib.matplotlib_fname()
# Out:
# '/usr/local/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
import matplotlib.pyplot as p

# %%
p.plot(range(20),range(20))

# %%
 p.show()

# %%
p.plot(list(range(200)), row[0:200])
p.title('Sample generated from RNN-Gauss')
# Out:
# Text(0.5, 1.0, 'Sample generated from RNN-Gauss')

# %%
file_path = '/Users/mariamma/Documents/phd/rnn_project/code/dataset/X_test_blizzard.csv'
x_df = pd.read_csv(file_path, header=None, nrows = 100)

# %%
x_row = x_df.iloc[2].to_numpy()

# %%
p.plot(list(range(200)), x_row)

# %%
from numpy import genfromtxt
my_data = genfromtxt('./loss.csv', delimiter=',')

# %%
len(my_data)
# Out:
# 35

# %%
p.plot(list(range(len(my_data))), my_data)
p.xlabel('Number of epochs')
p.ylabel('Loss value')
# Out:
# Text(0, 0.5, 'Loss value')
